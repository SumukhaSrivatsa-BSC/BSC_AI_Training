# %% [markdown]
# # Prompt Engineering — Practice Questions & Answers

# %% [markdown]
# ### Q1. You want an AI model to explain, in your own words, the difference between Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI. Write a complete prompt that asks the AI to explain these four concepts as layered ideas, using one real-world example for each, in language suitable for a first-year college student.

# %% [markdown]
# **Answer:**
#
# Walk me through Artificial Intelligence, Machine Learning, Deep Learning, and Generative AI as a set of nested ideas, showing how each one sits inside the last. Keep the wording simple enough for a first-year college student to follow, and attach one real-world example to each concept so the layering is easy to picture.

# %% [markdown]
# ### Q2. Write a prompt asking an AI model to explain how it processes a user's prompt, describing the stages of tokenization, understanding context, and predicting the next tokens, using a simple analogy a non-technical person would understand.

# %% [markdown]
# **Answer:**
#
# Describe, in plain terms, what happens inside an AI model when it processes something a user types — cover breaking the text into tokens, building an understanding of the context, and predicting the next token. Use an everyday analogy that someone with no technical background could relate to, and keep the tone approachable.

# %% [markdown]
# ### Q3. You want to understand why an AI model does not simply "search and copy" answers from the internet. Write a prompt requesting a clear explanation of how an LLM actually generates a response, including the role of probability in choosing the next word.

# %% [markdown]
# **Answer:**
#
# Clear up a common misconception: explain why a Large Language Model doesn't just look answers up online and copy them. Instead, describe how it builds a response by predicting each next word based on patterns it learned during training, and touch on how probability guides that word-by-word choice. One simple illustrative example would help.

# %% [markdown]
# ### Q4. Write a prompt asking the AI to explain what a "context window" is, why it has a limit, and what happens when a conversation exceeds that limit. Ask for the explanation to include a simple numeric example.

# %% [markdown]
# **Answer:**
#
# Explain what's meant by a model's "context window," why there's a cap on it in the first place, and what happens once a conversation runs past that cap. Include a small numbers-based example so the limit feels concrete rather than abstract, and keep the explanation approachable for a beginner.

# %% [markdown]
# ### Q5. Draft a prompt that asks the AI to compare "Training" and "Inference" side by side in a two-column format, describing what happens in each phase and when each one occurs.

# %% [markdown]
# **Answer:**
#
# Lay out "Training" and "Inference" side by side in a two-column comparison. For each phase, cover what actually happens, when it takes place in a model's lifecycle, and why it matters. Keep the language simple enough for someone new to the topic.

# %% [markdown]
# ### Q6. Write two versions of a prompt asking "What is Machine Learning?"—one vague/poor version and one improved version that adds a role, an audience, and a request for a real-world example. Explain in one sentence why the second version would produce a better response.

# %% [markdown]
# **Answer:**
#
# Weak version:
#
# What is Machine Learning?
#
# Stronger version:
#
# Take on the role of an AI instructor and explain Machine Learning to a first-year engineering student in plain English. Include one real-world example and briefly note why it matters in everyday life, keeping the whole answer under 200 words.
#
# Why it's better: giving the model a role, a target audience, and a concrete example request narrows down what kind of answer it should produce, so the result is more focused and useful.

# %% [markdown]
# ### Q7. Write a complete prompt using all six components of a good prompt (Role, Task, Context, Instructions, Constraints, Output Format) to ask an AI to explain "Cloud Computing" to a non-technical business owner.

# %% [markdown]
# **Answer:**
#
# Role: Act as a seasoned IT trainer.
# Task: Explain what Cloud Computing is.
# Context: You're speaking to a non-technical business owner.
# Instructions: Use plain wording and everyday comparisons; touch on its benefits and typical uses.
# Constraints: Skip technical jargon and stay under 250 words.
# Output Format: Present it with headings and bullet points.

# %% [markdown]
# ### Q8. Take the vague prompt "Write something for my manager" and rewrite it as a clear, complete prompt that specifies the role, the audience, the purpose of the message, a word limit, and the tone required.

# %% [markdown]
# **Answer:**
#
# Act as a business-writing assistant and draft an email to my manager letting them know I've wrapped up my assigned tasks and submitted all the required files. Keep it under 100 words, and make sure the tone is polite, respectful, and professional throughout.

# %% [markdown]
# ### Q9. Write a prompt using the Role component only, asking the AI to act as an experienced HR Manager, and then have it draft a short policy note about work-from-home guidelines.

# %% [markdown]
# **Answer:**
#
# Take on the role of a seasoned HR Manager and write a brief policy note outlining the company's work-from-home guidelines. Keep the tone professional but easy to follow.

# %% [markdown]
# ### Q10. Write a prompt that uses Context to help an AI understand a situation before responding: you are a final-year engineering student preparing for a job interview and need help answering "Tell me about yourself."

# %% [markdown]
# **Answer:**
#
# I'm a final-year engineering student getting ready for my first job interview. My background includes Python, Machine Learning, and SQL, a few academic projects, and a completed internship. Given that, help me put together a confident, natural-sounding answer to "Tell me about yourself" — something a fresher could comfortably deliver in about two minutes.

# %% [markdown]
# ### Q11. Write a prompt with Constraints only: ask the AI to explain "Blockchain Technology" in exactly 80 words, using no technical jargon.

# %% [markdown]
# **Answer:**
#
# Explain Blockchain Technology in exactly 80 words, with no technical jargon at all — write it so a complete beginner could follow along easily.

# %% [markdown]
# ### Q12. Design a reusable Prompt Template (using placeholders like [ROLE], [TASK], [CONTEXT], [INSTRUCTIONS], [CONSTRAINTS], [FORMAT]) that a new employee could reuse to ask the AI to explain any technical topic to any type of audience.

# %% [markdown]
# **Answer:**
#
# Role: [ROLE]
# Task: [TASK]
# Context: [CONTEXT]
# Instructions: [INSTRUCTIONS]
# Constraints: [CONSTRAINTS]
# Output Format: [FORMAT]
#
# Using the details filled in above, explain the topic in a way that fits the intended audience and follows every instruction given.

# %% [markdown]
# ### Q13. Write a Zero-Shot prompt asking the AI to classify the following review as Positive, Negative, or Neutral, without giving it any example: "The delivery was fast, but the packaging was damaged."

# %% [markdown]
# **Answer:**
#
# Sort the customer review below into Positive, Negative, or Neutral. Reply with just the category.
#
# Review: "The delivery was fast, but the packaging was damaged."

# %% [markdown]
# ### Q14. Write a One-Shot prompt that gives the AI one labeled example of classifying customer feedback into "Complaint" or "Compliment", and then asks it to classify a new piece of feedback of your choice.

# %% [markdown]
# **Answer:**
#
# Example:
#
# Feedback: "The support team solved my issue quickly."
# Category: Compliment
#
# Now sort the feedback below into either Complaint or Compliment.
#
# Feedback: "The product arrived three days late and the box was broken."

# %% [markdown]
# ### Q15. Write a Few-Shot prompt that gives at least three labeled examples of classifying a sentence's tone as Formal or Informal, and then asks the AI to classify two new sentences.

# %% [markdown]
# **Answer:**
#
# Example 1:
# Sentence: "Please submit the report by Friday."
# Tone: Formal
#
# Example 2:
# Sentence: "Hey, can you send it today?"
# Tone: Informal
#
# Example 3:
# Sentence: "Kindly attend the meeting at 10 AM."
# Tone: Formal
#
# Now label the tone of these two sentences:
# 1. "Thanks a lot for your help!"
# 2. "I would appreciate your response at your earliest convenience."

# %% [markdown]
# ### Q16. Write a prompt that uses delimiters (triple quotes, dashes, or XML-style tags) to clearly separate your instructions from a block of sample text you want summarized, and explain in one sentence why delimiters reduce confusion for the model.

# %% [markdown]
# **Answer:**
#
# Summarize the text below into 5 short bullet points.
#
# """
# Artificial Intelligence is changing many industries by improving automation, decision-making, and customer service. Many companies use AI to save time, reduce costs, and improve accuracy.
# """
#
# Why delimiters help: wrapping the sample text in clear markers keeps it visually distinct from the instructions, so the model doesn't accidentally treat part of the instructions as content to summarize (or vice versa).

# %% [markdown]
# ### Q17. Write a three-step prompt refinement exercise: (a) a poor prompt asking the AI to "explain databases", (b) an improved version adding audience and language style, and (c) a final version adding a word-limit constraint and a required output structure.

# %% [markdown]
# **Answer:**
#
# (a) Weak version:
# Explain databases.
#
# (b) Improved version:
# Explain databases to a first-year engineering student, using simple wording and relatable everyday examples.
#
# (c) Final version:
# Explain databases to a first-year engineering student in plain English, staying under 150 words. Structure the answer under these headings: Definition, Features, Advantages, and Example.

# %% [markdown]
# ### Q18. Write a Role + Context combined prompt where the AI acts as a "Career Counsellor" and uses context about a student's background (choose your own details) to recommend three suitable career paths.

# %% [markdown]
# **Answer:**
#
# Take on the role of an experienced Career Counsellor. A student has finished a B.Tech in Computer Science, enjoys programming in Python, has a working knowledge of Machine Learning, and likes tackling problems. Based on that profile, suggest three career paths that would suit them, explain why each is a good fit, and list the skills needed for each.

# %% [markdown]
# ### Q19. Write a Chain-of-Thought prompt that asks the AI to solve, step by step, the following problem: a shop offers a 15% discount on a product priced at ₹3,500, and then adds 5% tax on the discounted price — what is the final amount to be paid?

# %% [markdown]
# **Answer:**
#
# Work through the problem below step by step, showing each calculation before stating the final answer.
#
# A product is priced at ₹3,500. The shop applies a 15% discount to the original price, and then adds 5% tax on top of the discounted price. What is the final amount the customer needs to pay?

# %% [markdown]
# ### Q20. Write a Self-Consistency prompt that asks the AI to solve a distance/speed/time problem of your choice using two different approaches and then select the most reliable final answer.

# %% [markdown]
# **Answer:**
#
# Solve the problem below using two different methods, and compare what each one gives you. If they agree, present that as the final answer along with a short note on why it's trustworthy.
#
# A car covers 240 km travelling at 60 km/h. How long does the trip take?

# %% [markdown]
# ### Q21. Write a Step-Back prompt that first asks the AI to identify the general principle behind why two products with the same features can have very different prices, before applying that principle to a specific example.

# %% [markdown]
# **Answer:**
#
# First, lay out the general factors that explain why two products with near-identical features can be priced very differently — think brand reputation, build quality, after-sales support, and marketing spend. Then apply those factors to compare two smartphones that have similar specs but very different price tags. Keep the language simple and grounded in real-life examples.

# %% [markdown]
# ### 22. Write a Prompt Decomposition sequence (at least 4 smaller prompts) that breaks the large task "Create a complete social media marketing plan for a new bakery" into smaller, manageable prompts.

# %% [markdown]
# **Answer:**
#
# Step 1:
# Describe the target audience for a new bakery and what they'd likely be interested in.
#
# Step 2:
# Recommend which social media platforms would work best for promoting the bakery, and explain the reasoning.
#
# Step 3:
# Put together a one-week content calendar with a post idea for each day.
#
# Step 4:
# Suggest marketing tactics, promotional offers, and ways to track whether the campaign is working.

# %% [markdown]
# ### 23. Write a three-prompt Prompt Chain where the output of each prompt feeds into the next: Prompt 1 extracts key points from a long article, Prompt 2 turns those key points into a summary, and Prompt 3 turns the summary into a 5-slide presentation outline.

# %% [markdown]
# **Answer:**
#
# Step 1:
# Go through the article and pull out the 10 most important points.
#
# Step 2:
# Turn the key points from Step 1 into a roughly 150-word summary.
#
# Step 3:
# Using that summary, build a 5-slide presentation outline, giving each slide a title and a few bullet points.

# %% [markdown]
# ### 24. Write a Self-Reflection prompt that asks the AI to first answer a question of your choice, then review its own answer for factual errors, missing information, and unclear explanations, and finally provide an improved version.

# %% [markdown]
# **Answer:**
#
# Explain the benefits Artificial Intelligence brings to education. Once you've written the answer, go back over it looking for factual mistakes, gaps in coverage, or anything unclear. Then produce a revised, improved version in simple English.

# %% [markdown]
# ### 25. Write a Critique-and-Revise prompt in which the AI first drafts a short apology email to a client for a delayed delivery, then critiques its own draft for tone and clarity, and finally produces a revised version.

# %% [markdown]
# **Answer:**
#
# Draft a brief apology email to a client about a delayed product delivery. Afterward, critique your own draft on tone, clarity, and professionalism, note any weak spots, and then rewrite the email addressing those issues.

# %% [markdown]
# ### 26. Write a Text Generation prompt asking the AI to act as a professional content writer and produce a 300-word LinkedIn post announcing a new AI training program at Cambridge Infotech, aimed at working professionals.

# %% [markdown]
# **Answer:**
#
# Act as a professional content writer and put together a roughly 300-word LinkedIn post announcing a new AI Training Program at Cambridge Infotech, aimed at working professionals. Cover what the course offers, its hands-on/practical angle, its relevance to industry, and end with a call to register. Keep the tone professional but engaging.

# %% [markdown]
# ### 27. Write a Summarization prompt that asks the AI to condense a long research article into exactly 5 bullet points, focusing only on the key findings and ignoring background information.

# %% [markdown]
# **Answer:**
#
# Condense the research article below into exactly 5 bullet points, focusing purely on the key findings — skip the background, introduction, and any other filler. Keep each bullet brief and to the point.

# %% [markdown]
# ### 28. Write a Classification prompt that asks the AI to classify five sample customer support messages (write the five messages yourself) into "Complaint", "Inquiry", or "Feedback", and return only the category for each.

# %% [markdown]
# **Answer:**
#
# Sort each customer message below into Complaint, Inquiry, or Feedback. Just return the category for each — no extra text.
#
# Messages:
# 1. My order has not arrived yet.
# 2. What are your delivery charges?
# 3. Your mobile app is very easy to use.
# 4. I received a damaged product.
# 5. Do you offer a student discount?

# %% [markdown]
# ### 29. Write an Information Extraction prompt that asks the AI to extract Name, Job Title, Years of Experience, and Key Skills from a short candidate profile you write yourself (2–3 sentences).

# %% [markdown]
# **Answer:**
#
# Pull out the following details from the candidate profile below: Name, Job Title, Years of Experience, and Key Skills.
#
# Candidate Profile:
# "Riya Sharma is a Data Analyst with 4 years of experience. She is skilled in Python, SQL, Power BI, and Excel. She enjoys analyzing business data and creating reports."

# %% [markdown]
# ### 30. Write a Translation prompt that asks the AI to translate a short paragraph about renewable energy into Hindi, while preserving technical terms and using natural, everyday language.

# %% [markdown]
# **Answer:**
#
# Translate the paragraph below into Hindi. Where useful, keep technical terms like solar energy, wind energy, and renewable energy in their commonly recognized form. Aim for natural, conversational Hindi that's easy to read.
#
# Paragraph:
# "Renewable energy is becoming more important because it helps reduce pollution and protects the environment. Solar energy and wind energy are clean sources of power that can meet future energy needs."

# %% [markdown]
# ### 31. Write a Rewriting/Transformation prompt that asks the AI to take a casual message ("hey can u pls send the report by tmrw eod, thanks") and rewrite it in three tones: Professional, Friendly, and Formal.

# %% [markdown]
# **Answer:**
#
# Rewrite the message below in three different tones — Professional, Friendly, and Formal — while keeping the original meaning intact.
#
# Message: "hey can u pls send the report by tmrw eod, thanks"

# %% [markdown]
# ### 32. Write a Context-Based Question-Answering prompt that provides a short paragraph of background information (write 3–4 sentences about any topic) and then asks the AI to answer a specific question using only that provided context.

# %% [markdown]
# **Answer:**
#
# Read the paragraph below and answer the question using only the information it contains.
#
# Paragraph:
# "Electric vehicles (EVs) use electricity instead of petrol or diesel. They produce less pollution and are better for the environment. Many governments are encouraging people to use EVs by offering subsidies. Charging stations are also increasing in many cities."
#
# Question: Why are governments encouraging people to use electric vehicles?

# %% [markdown]
# ### 33. Write a prompt that asks the AI to explain the advantages of remote work in exactly 6 bullet points, with no additional explanation before or after the list.

# %% [markdown]
# **Answer:**
#
# List exactly 6 bullet points covering the advantages of remote work. Don't add any introduction, conclusion, or commentary before or after the list — just the bullets.

# %% [markdown]
# ### 34. Write a prompt that asks the AI to compare "Machine Learning" and "Deep Learning" in a table, with columns for Definition, Data Requirement, and Typical Use Case.

# %% [markdown]
# **Answer:**
#
# Put Machine Learning and Deep Learning side by side in a table, with these columns: Definition, Data Requirement, and Typical Use Case. Keep the wording simple enough for a beginner.

# %% [markdown]
# ### 35. Write a JSON-based prompt (including a defined schema with field names such as name, role, experience_years, and skills as an array) that asks the AI to extract structured candidate information from a short resume paragraph you write yourself.

# %% [markdown]
# **Answer:**
#
# Pull the details out of the candidate profile below and format them according to the JSON schema shown.
#
# Schema:
# {
#   "name": "",
#   "role": "",
#   "experience_years": "",
#   "skills": []
# }
#
# Candidate Profile:
# "Anjali Verma is a Software Engineer with 5 years of experience. She is skilled in Python, Java, SQL, and Git."

# %% [markdown]
# ### 36. Write a prompt that asks the AI to return the same candidate information as XML instead of JSON, using appropriate opening and closing tags.

# %% [markdown]
# **Answer:**
#
# Pull the details out of the candidate profile below and return them as XML, using properly matched opening and closing tags.
#
# Candidate Profile:
# "Anjali Verma is a Software Engineer with 5 years of experience. She is skilled in Python, Java, SQL, and Git."

# %% [markdown]
# ### 37. Write a Schema-Based prompt for extracting product review data (fields: product_name, rating, sentiment, main_complaint) and explicitly instruct the AI to return null for any field it cannot determine, rather than guessing.

# %% [markdown]
# **Answer:**
#
# Extract the following fields from the review below: product_name, rating, sentiment, main_complaint. Return the result as JSON. If a field can't be determined from the text, set it to null instead of guessing at a value.
#
# Review:
# "The headphones have excellent sound quality, but the battery lasts only a few hours."

# %% [markdown]
# ### 38. Write a prompt that combines multiple output constraints at once: classify a customer complaint into one of three fixed categories (Billing, Product, Delivery), identify the main issue, suggest a solution, and return the entire result as a single JSON object.

# %% [markdown]
# **Answer:**
#
# Read the complaint below and classify it into exactly one of these categories: Billing, Product, or Delivery. Identify the core issue, propose a reasonable solution, and package everything into a single JSON object.
#
# Complaint:
# "I received the wrong item and the replacement has not arrived yet."

# %% [markdown]
# ### 39. Write a prompt asking the AI to convert a plain-language business requirement ("find all customers who spent more than ₹10,000 last month") into a CSV-style output listing sample matching records, with clearly labeled columns.

# %% [markdown]
# **Answer:**
#
# Turn the business requirement below into a CSV-style table of sample matching records, with clearly labeled columns.
#
# Requirement: "Find all customers who spent more than ₹10,000 last month."
#
# Columns to include: Customer_ID, Customer_Name, Total_Spent, Month.

# %% [markdown]
# ### 40. Write a complete code-generation prompt (Role + Language + Task + Requirements + Input + Output) asking the AI to write a Python function that checks whether a given number is a prime number, including error handling for negative numbers.

# %% [markdown]
# **Answer:**
#
# Role: You're an experienced Python developer.
# Language: Python
# Task: Write a function that checks whether a given number is prime.
# Requirements: Handle negative numbers by showing a clear error message; use readable variable names; comment the code; keep it beginner-friendly.
# Input: A single integer entered by the user.
# Output: State whether the number is prime, or show an error message if the input is negative.

# %% [markdown]
# ### 41. Write a prompt asking the AI to explain a piece of Python code (of your choice, at least 5 lines) line by line to a complete beginner, explaining both what each line does and why it is used.

# %% [markdown]
# **Answer:**
#
# Go through the Python code below line by line for someone with zero coding background — explain what each line does and why it's needed. Avoid technical jargon.
#
# numbers = [10, 20, 30, 40]
# total = sum(numbers)
# average = total / len(numbers)
# print("Total:", total)
# print("Average:", average)

# %% [markdown]
# ### 42. Write a Debugging prompt that provides a short piece of buggy code, the exact error message it produces, and the expected output, and asks the AI to explain the cause of the error and provide corrected code.

# %% [markdown]
# **Answer:**
#
# The Python code below throws an error. Explain what's causing it, fix the code, and walk through what changed.
#
# Code:
# numbers = [1, 2, 3]
# print(numbers[5])
#
# Error Message:
# IndexError: list index out of range
#
# Expected Output:
# Print the last number in the list.

# %% [markdown]
# ### 43. Write a Code Optimization prompt asking the AI to improve the performance of a given Python function while preserving its exact output, and to explain the changes made using a before-and-after comparison.

# %% [markdown]
# **Answer:**
#
# Improve the performance of the Python function below without changing what it outputs. Explain the improvements with a before-and-after comparison, and keep the optimized version easy to read.
#
# def find_even(numbers):
#     result = []
#     for num in numbers:
#         if num % 2 == 0:
#             result.append(num)
#     return result

# %% [markdown]
# ### 44. Write a prompt asking the AI to refactor a messy piece of code by adding proper functions, meaningful variable names, and PEP 8 formatting, without changing its final output.

# %% [markdown]
# **Answer:**
#
# Refactor the Python code below: wrap the logic in a proper function, use meaningful variable names, add helpful comments, and follow PEP 8 style. The final output must stay the same.
#
# a=[10,20,30]
# s=0
# for i in a:
#  s=s+i
# print(s)

# %% [markdown]
# ### 45. Write a prompt asking the AI to generate unit test cases (3 normal cases, 2 edge cases, and 2 invalid-input cases) for a function that calculates the average of a list of numbers, using Python's unittest framework.

# %% [markdown]
# **Answer:**
#
# Write unit tests, using Python's unittest framework, for a function that computes the average of a list of numbers. Include 3 normal cases, 2 edge cases, and 2 invalid-input cases, and add a comment explaining what each test checks.

# %% [markdown]
# ### 46. Write a prompt asking the AI to convert a business requirement ("list all employees whose department is Sales and salary is above ₹60,000") into a correct SQL query, given a table named employees with columns employee_id, name, department, and salary.

# %% [markdown]
# **Answer:**
#
# Turn the business requirement below into a correct SQL query.
#
# Requirement: "List all employees whose department is Sales and salary is above ₹60,000."
#
# Table: employees
# Columns: employee_id, name, department, salary
#
# Return just the properly formatted SQL query.

# %% [markdown]
# ### 47. Write a Dataset Understanding prompt asking the AI to act as a senior data analyst and describe the number of rows, columns, data types, missing values, and possible data quality issues in a dataset you describe briefly.

# %% [markdown]
# **Answer:**
#
# Act as a Senior Data Analyst. I have a sales dataset with 5,000 rows and 6 columns: Order_ID, Date, Product, Region, Quantity, and Revenue. Walk me through the likely row/column counts, data types, potential missing values, and possible data quality issues. Use plain language and organize your answer under headings.

# %% [markdown]
# ### 48. Write a Data Cleaning prompt asking the AI to identify columns with missing values in a given dataset description and suggest the most appropriate treatment method for each.

# %% [markdown]
# **Answer:**
#
# Act as a Data Analyst. A customer dataset has the columns Name, Age, City, Email, and Salary, with some values missing in Age, City, and Salary. Point out which columns have gaps and recommend the best cleaning approach for each one, explained simply.

# %% [markdown]
# ### 49. Write an Exploratory Data Analysis (EDA) prompt asking the AI to identify important patterns, outliers, and relationships between variables in a sales dataset containing Date, Product, Region, and Revenue columns.

# %% [markdown]
# **Answer:**
#
# Act as a Data Analyst and run through an Exploratory Data Analysis on a sales dataset with the columns Date, Product, Region, and Revenue. Call out notable patterns, trends, outliers, and relationships between the variables, and surface any useful insights. Present it with headings and bullet points, in plain English.

# %% [markdown]
# ### 50. Write a Data Visualization prompt asking the AI to suggest three appropriate charts for a dataset (state the chart type, the X-axis, the Y-axis, and the business question each chart answers) for the sales dataset above.

# %% [markdown]
# **Answer:**
#
# Act as a Data Analyst. For the sales dataset with columns Date, Product, Region, and Revenue, suggest three charts worth building. For each one, specify the chart type, what goes on the X-axis, what goes on the Y-axis, and which business question it answers. Briefly explain why each chart is useful.

# %% [markdown]
# ### 51. Write a Machine Learning Model Selection prompt that describes a dataset with a target variable of "Customer_Churn" and asks the AI to suggest suitable algorithms, why each is appropriate, key preprocessing steps, and evaluation metrics to use.

# %% [markdown]
# **Answer:**
#
# Act as an experienced Machine Learning Engineer. I have a customer dataset where the target variable, Customer_Churn, indicates whether a customer leaves or stays. Recommend algorithms suited to this classification problem, explain why each fits, outline the key preprocessing steps, and suggest evaluation metrics for measuring performance. Present the answer with headings and bullet points in plain English.

# %% [markdown]
# ### 52. Write a Business Insight prompt asking the AI to analyze a dataset from a business perspective and identify important trends, risks, opportunities, and recommended actions, rather than just describing the numbers.

# %% [markdown]
# **Answer:**
#
# Act as a Business Data Analyst. Rather than just describing the raw numbers, analyze a sales dataset from a business standpoint — surface important trends, risks, growth opportunities, and practical recommendations for improving performance. Use plain English and organize your answer under clear headings.

# %% [markdown]
# ### 53. Write a full Data Analysis Prompt Template (using placeholders for Role, Dataset description, Business Objective, and Tasks) that could be reused for any new dataset your team receives in the future.

# %% [markdown]
# **Answer:**
#
# Role: [ROLE]
# Dataset Description: [DATASET_DESCRIPTION]
# Business Objective: [BUSINESS_OBJECTIVE]
#
# Tasks:
# 1. Understand the dataset's structure.
# 2. Check data types and missing values.
# 3. Flag any data quality issues.
# 4. Suggest appropriate cleaning methods.
# 5. Perform Exploratory Data Analysis (EDA).
# 6. Identify trends, patterns, and outliers.
# 7. Recommend suitable visualizations.
# 8. Suggest machine learning models if relevant.
# 9. Provide business insights and actionable recommendations.
#
# Output Format:
# - Dataset Overview
# - Data Quality Report
# - Data Cleaning Suggestions
# - EDA Findings
# - Visualization Recommendations
# - Machine Learning Suggestions (if applicable)
# - Business Insights
# - Final Recommendations
